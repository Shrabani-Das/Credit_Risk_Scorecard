# %% [markdown]
# # Objective
# The objective of this notebook is to create predictive credit risk features, prepare variables for scorecard development, perform WOE binning, and evaluate predictor strength using Information Value (IV).
